# %%
print("Vigensh")
# Out:
# Vigensh

# %%
name="Vignesh"
age=20
height=6.2
print(f"{name}{age}{height}")
# Out:
# Vignesh206.2

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
a=int(input())
if(a>=18):
    {print("You are eligible for voting")}
else:
    print("You are not eligible for voting")
# Out:
# You are not eligible for voting

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a= int(input())
prime=[]

for i in range(2,a+1):
    is_prime=True
    for j in range(2,i):
        if(i%j==0):
            is_prime=False
            break
    if(is_prime):
        prime.append(i)
print(prime)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19, 23]

# %%
name="Vignesh"

# %%
name.startswith("V")
name.endswith("H")
name.__contains__("Vigne")
name[5]
name.index("i")
list(name)
name.replace("V","v")
name.replaceall("[aeiou]"," ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 8
#       6 list(name)
#       7 name.replace("V","v")
# ----> 8 name.replaceall("[aeiou]"," ")
#
# AttributeError: 'str' object has no attribute 'replaceall'
